# %%
# IMPORT LIBRARY
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
import keras

# %%
# IMPORT DATA
dataset = pd.read_csv("../dataset/datasetmerged_duplicate8x.csv")
dataset
# Out:
#                                                   Title        Type BodyPart  \
# 0                                      Single-Leg Press    Strength    Thigh
# 1     Incline Hammer Curls, Palms-down wrist curl ov...    Strength   Biceps
# 2                                        Landmine twist    Strength    Waist
# 3            Palms-up wrist curl over bench, Biceps dip    Strength   Biceps
# 4     Barbell Deadlift, Romanian Deadlift With Dumbb...    Strength    Thigh
# ...                                                 ...         ...      ...
# 1083                     Standing Elevated Quad Stretch  Stretching    Thigh
# 1084                                      Wrist Circles  Stretching   Biceps
# 1085  IT Band and Glute Stretch, Chair Leg Extended ...  Stretching    Thigh
# 1086                Single-leg lying cross-over stretch  Stretching    Thigh
# 1087  Seated wide-grip curl to close-grip curl, Seat...    Strength   Biceps
#
#       Rating
# 0        9.6
# 1        9.5
# 2        9.5
# 3        9.4
# 4        9.4
# ...      ...
# 1083     2.7
# 1084     2.5
# 1085     2.4
# 1086     1.6
# 1087     0.0
#
# [1088 rows x 4 columns]

# %%
#LABEL & FITUR
label = dataset['Title']
fitur = ['BodyPart','Type', 'Rating']
fitur = dataset[fitur]
fitur
# Out:
#      BodyPart        Type  Rating
# 0       Thigh    Strength     9.6
# 1      Biceps    Strength     9.5
# 2       Waist    Strength     9.5
# 3      Biceps    Strength     9.4
# 4       Thigh    Strength     9.4
# ...       ...         ...     ...
# 1083    Thigh  Stretching     2.7
# 1084   Biceps  Stretching     2.5
# 1085    Thigh  Stretching     2.4
# 1086    Thigh  Stretching     1.6
# 1087   Biceps    Strength     0.0
#
# [1088 rows x 3 columns]

# %%
label
# Out:
# 0                                        Single-Leg Press
# 1       Incline Hammer Curls, Palms-down wrist curl ov...
# 2                                          Landmine twist
# 3              Palms-up wrist curl over bench, Biceps dip
# 4       Barbell Deadlift, Romanian Deadlift With Dumbb...
#                               ...
# 1083                       Standing Elevated Quad Stretch
# 1084                                        Wrist Circles
# 1085    IT Band and Glute Stretch, Chair Leg Extended ...
# 1086                  Single-leg lying cross-over stretch
# 1087    Seated wide-grip curl to close-grip curl, Seat...
# Name: Title, Length: 1088, dtype: object

# %%
features_encoded = pd.get_dummies(fitur, columns=['BodyPart', 'Type'])
features_encoded
# Out:
#       Rating  BodyPart_Biceps  BodyPart_Thigh  BodyPart_Waist  Type_Cardio  \
# 0        9.6            False            True           False        False
# 1        9.5             True           False           False        False
# 2        9.5            False           False            True        False
# 3        9.4             True           False           False        False
# 4        9.4            False            True           False        False
# ...      ...              ...             ...             ...          ...
# 1083     2.7            False            True           False        False
# 1084     2.5             True           False           False        False
# 1085     2.4            False            True           False        False
# 1086     1.6            False            True           False        False
# 1087     0.0             True           False           False        False
#
#       Type_Strength  Type_Stretching
# 0              True            False
# 1              True            False
# 2              True            False
# 3              True            False
# 4              True            False
# ...             ...              ...
# 1083          False             True
# 1084          False             True
# 1085          False             True
# 1086          False             True
# 1087           True            False
#
# [1088 rows x 7 columns]

# %%
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(label)
labels_encoded = labels_encoded.reshape(-1, 1)
labels_encoded
# Out:
# array([[101],
#        [ 51],
#        [ 58],
#        ...,
#        [ 48],
#        [105],
#        [ 98]])

# %%
features_encoded = features_encoded.to_numpy()
features_encoded = features_encoded.astype(float)
features_encoded
# Out:
# array([[9.6, 0. , 1. , ..., 0. , 1. , 0. ],
#        [9.5, 1. , 0. , ..., 0. , 1. , 0. ],
#        [9.5, 0. , 0. , ..., 0. , 1. , 0. ],
#        ...,
#        [2.4, 0. , 1. , ..., 0. , 0. , 1. ],
#        [1.6, 0. , 1. , ..., 0. , 0. , 1. ],
#        [0. , 1. , 0. , ..., 0. , 1. , 0. ]])

# %%
print(features_encoded.shape)
print(labels_encoded.shape)
# Out:
# (1088, 7)
# (1088, 1)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, input_dim=features_encoded.shape[1], activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(136, activation='softmax')
])
model.summary()
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(features_encoded, labels_encoded, epochs=100, batch_size=16)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_76 (Dense)            (None, 128)               1024
#
#  dense_77 (Dense)            (None, 256)               33024
#
#  dense_78 (Dense)            (None, 128)               32896
#
#  dense_79 (Dense)            (None, 136)               17544
#
# =================================================================
# Total params: 84488 (330.03 KB)
# Trainable params: 84488 (330.03 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 68/68 [==============================] - 1s 3ms/step - loss: 4.9137 - accuracy: 0.0138
# Epoch 2/100
# 68/68 [==============================] - 0s 2ms/step - loss: 4.6638 - accuracy: 0.0239
# Epoch 3/100
# 68/68 [==============================] - 0s 2ms/step - loss: 3.8412 - accuracy: 0.0570
# Epoch 4/100
# 68/68 [==============================] - 0s 2ms/step - loss: 3.2815 - accuracy: 0.0616
# Epoch 5/100
# 68/68 [==============================] - 0s 3ms/step - loss: 3.0040 - accuracy: 0.1039
# Epoch 6/100
# 68/68 [==============================] - 0s 3ms/step - loss: 2.7944 - accuracy: 0.1287
# Epoch 7/100
# 68/68 [==============================] - 0s 2ms/step - loss: 2.6163 - accuracy: 0.1351
# Epoch 8/100
# 68/68 [==============================] - 0s 2ms/step - loss: 2.4574 - accuracy: 0.1774
# Epoch 9/100
# 68/68 [==============================] - 0s 3ms/step - loss: 2.3209 - accuracy: 0.2031
# Epoch 10/100
# 68/68 [==============================] - 0s 3ms/step - loss: 2.2364 - accuracy: 0.2169
# Epoch 11/100
# 68/68 [==============================] - 0s 2ms/step - loss: 2.1407 - accuracy: 0.2188
# Epoch 12/100
# 68/68 [==============================] - 0s 2ms/step - loss: 2.0567 - accuracy: 0.2408
# Epoch 13/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.9763 - accuracy: 0.2767
# Epoch 14/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.8803 - accuracy: 0.3024
# Epoch 15/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.8318 - accuracy: 0.3070
# Epoch 16/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.7805 - accuracy: 0.3346
# Epoch 17/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.7225 - accuracy: 0.3520
# Epoch 18/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.6809 - accuracy: 0.3575
# Epoch 19/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.6580 - accuracy: 0.3732
# Epoch 20/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.6509 - accuracy: 0.3897
# Epoch 21/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.5761 - accuracy: 0.3897
# Epoch 22/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.5775 - accuracy: 0.3631
# Epoch 23/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.4929 - accuracy: 0.4017
# Epoch 24/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.4859 - accuracy: 0.3943
# Epoch 25/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.4397 - accuracy: 0.4357
# Epoch 26/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.4161 - accuracy: 0.4237
# Epoch 27/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.4106 - accuracy: 0.4219
# Epoch 28/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.3760 - accuracy: 0.4568
# Epoch 29/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.3464 - accuracy: 0.4504
# Epoch 30/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.3253 - accuracy: 0.4632
# Epoch 31/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.3123 - accuracy: 0.4678
# Epoch 32/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.2525 - accuracy: 0.4945
# Epoch 33/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.2816 - accuracy: 0.4807
# Epoch 34/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.2299 - accuracy: 0.4954
# Epoch 35/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.2168 - accuracy: 0.4954
# Epoch 36/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.1864 - accuracy: 0.5248
# Epoch 37/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.2472 - accuracy: 0.4844
# Epoch 38/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.1641 - accuracy: 0.5221
# Epoch 39/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.1473 - accuracy: 0.5285
# Epoch 40/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.2135 - accuracy: 0.4982
# Epoch 41/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.1645 - accuracy: 0.5248
# Epoch 42/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0965 - accuracy: 0.5358
# Epoch 43/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.1029 - accuracy: 0.5542
# Epoch 44/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.1108 - accuracy: 0.5303
# Epoch 45/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0931 - accuracy: 0.5653
# Epoch 46/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.0446 - accuracy: 0.5551
# Epoch 47/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0223 - accuracy: 0.5744
# Epoch 48/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0363 - accuracy: 0.5625
# Epoch 49/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.9998 - accuracy: 0.5827
# Epoch 50/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0661 - accuracy: 0.5432
# Epoch 51/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0296 - accuracy: 0.5790
# Epoch 52/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.9962 - accuracy: 0.5754
# Epoch 53/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.0417 - accuracy: 0.5524
# Epoch 54/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.9990 - accuracy: 0.5717
# Epoch 55/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.9337 - accuracy: 0.6222
# Epoch 56/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.9461 - accuracy: 0.6103
# Epoch 57/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0077 - accuracy: 0.5790
# Epoch 58/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0148 - accuracy: 0.5414
# Epoch 59/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.9126 - accuracy: 0.6250
# Epoch 60/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.9031 - accuracy: 0.6002
# Epoch 61/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.9061 - accuracy: 0.6305
# Epoch 62/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8816 - accuracy: 0.6342
# Epoch 63/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8991 - accuracy: 0.6121
# Epoch 64/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8917 - accuracy: 0.6186
# Epoch 65/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8514 - accuracy: 0.6471
# Epoch 66/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.9039 - accuracy: 0.6020
# Epoch 67/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8591 - accuracy: 0.6241
# Epoch 68/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.8439 - accuracy: 0.6507
# Epoch 69/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8301 - accuracy: 0.6526
# Epoch 70/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.8490 - accuracy: 0.6305
# Epoch 71/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8252 - accuracy: 0.6544
# Epoch 72/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.8531 - accuracy: 0.6324
# Epoch 73/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.8681 - accuracy: 0.6324
# Epoch 74/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.8747 - accuracy: 0.6535
# Epoch 75/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8950 - accuracy: 0.6075
# Epoch 76/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8191 - accuracy: 0.6535
# Epoch 77/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8549 - accuracy: 0.6452
# Epoch 78/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.8967 - accuracy: 0.6268
# Epoch 79/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7529 - accuracy: 0.6838
# Epoch 80/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7820 - accuracy: 0.6820
# Epoch 81/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7607 - accuracy: 0.6801
# Epoch 82/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7333 - accuracy: 0.7086
# Epoch 83/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7720 - accuracy: 0.6765
# Epoch 84/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7222 - accuracy: 0.6985
# Epoch 85/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7857 - accuracy: 0.6507
# Epoch 86/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7238 - accuracy: 0.7068
# Epoch 87/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6726 - accuracy: 0.7325
# Epoch 88/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6736 - accuracy: 0.7261
# Epoch 89/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8707 - accuracy: 0.6103
# Epoch 90/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8401 - accuracy: 0.6388
# Epoch 91/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7044 - accuracy: 0.7040
# Epoch 92/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6724 - accuracy: 0.7417
# Epoch 93/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7161 - accuracy: 0.6903
# Epoch 94/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.7889 - accuracy: 0.6618
# Epoch 95/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.7980 - accuracy: 0.6507
# Epoch 96/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7147 - accuracy: 0.6976
# Epoch 97/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7024 - accuracy: 0.6921
# Epoch 98/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6267 - accuracy: 0.7399
# Epoch 99/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6052 - accuracy: 0.7739
# Epoch 100/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.7212 - accuracy: 0.6912
